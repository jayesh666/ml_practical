# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('ML_P_3.csv')
x = data.iloc[:, 0]
y = data.iloc[:, 1]
plt.xlabel("Years of experience")
plt.ylabel("Salary")
plt.scatter(x, y)
